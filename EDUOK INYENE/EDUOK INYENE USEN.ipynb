# %% [markdown]
# # EDUOK INYENE USEN
#
# ## 18CJ024116
#
# ## COMPUTER ENGINEERING

# %% [markdown]
# # ANNUAL NUMBER OF CRUDE BIRTH RATE IN AFRICA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics as sta

df = pd.read_csv('data.csv')

for i in range (2011, 2021, 1):
    
    x = df["COUNTRIES"]
    y = df[f"{i-1}"]
    
    s_deviation = y.std()
    
    maximum_val = y.max()
    minimum_val = y.min()
    Range_val = maximum_val - minimum_val
    
    variance_val = sta.variance(df[f"{i-1}"])

    plt.figure(figsize =(35, 20))
    plt.barh(x, y, height = 0.7)
    plt.title(f"ANNUAL NUMBER OF BIRTH RATE IN {i-1}", fontsize = 30)
    plt.xlabel('Birth Rate per 1000 Citizens', fontsize = 30)
    plt.xticks(fontsize = 25)
    plt.yticks(fontsize = 20)
    plt.show()
    
    print(f'The Standard Deviation is {s_deviation}')
    print(f'The Range is {Range_val}')
    print(f'The Variance is {variance_val}')
# Out:
# The Standard Deviation is 5.29666933394775
# The Range is 25.0
# The Variance is 28.054706033182505
# The Standard Deviation is 6.600807585766587
# The Range is 41.160000000000004
# The Variance is 43.57066078431373
# The Standard Deviation is 5.315888628253414
# The Range is 24.0
# The Variance is 28.258671907993964
# The Standard Deviation is 4.160877089309159
# The Range is 22.0
# The Variance is 17.312898152337855
# The Standard Deviation is 4.84186065400071
# The Range is 24.0
# The Variance is 23.44361459276018
# The Standard Deviation is 4.149170677098293
# The Range is 17.0
# The Variance is 17.21561730769231
# The Standard Deviation is 4.715605874455328
# The Range is 20.22
# The Variance is 22.236938763197585
# The Standard Deviation is 4.715605874455328
# The Range is 20.22
# The Variance is 22.236938763197585
# The Standard Deviation is 95.48662952114128
# The Range is 575.0
# The Variance is 9117.696417307692
# The Standard Deviation is 3.525738003465365
# The Range is 13.0
# The Variance is 12.43082846907994
